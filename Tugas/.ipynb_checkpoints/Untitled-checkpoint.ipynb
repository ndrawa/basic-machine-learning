# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')

# %%
df_ytb_all = pd.read_csv('./datasets/Tugas1.csv')
df_ytb_all
# Out:
#            No.         Time                     Source      Destination  \
# 0            1     0.000000                172.20.10.5     172.20.10.15
# 1            2     0.000919  fe80::4c41:db99:348b:6ce1        ff02::1:3
# 2            3     0.001293                172.20.10.5      224.0.0.252
# 3            4     0.415332  fe80::4c41:db99:348b:6ce1        ff02::1:3
# 4            5     0.415720                172.20.10.5      224.0.0.252
# ...        ...          ...                        ...              ...
# 129703  129704  2018.557236                172.20.10.5     74.125.24.93
# 129704  129705  2018.646673                172.20.10.5  239.255.255.250
# 129705  129706  2018.670811               74.125.24.93      172.20.10.5
# 129706  129707  2018.670811               74.125.24.93      172.20.10.5
# 129707  129708  2018.671179                172.20.10.5     74.125.24.93
#
#        Protocol  Length                          Info
# ...

# %%
df_ytb_all = pd.read_csv('./datasets/Tugas1.csv')
#df_ytb_all = df_ytb_all[(df_ytb_all['Source'] == '74.125.10.24') | (df_ytb_all['Destination'] == '74.125.10.24')]
df_ytb_all
# Out:
#            No.         Time                     Source      Destination  \
# 0            1     0.000000                172.20.10.5     172.20.10.15
# 1            2     0.000919  fe80::4c41:db99:348b:6ce1        ff02::1:3
# 2            3     0.001293                172.20.10.5      224.0.0.252
# 3            4     0.415332  fe80::4c41:db99:348b:6ce1        ff02::1:3
# 4            5     0.415720                172.20.10.5      224.0.0.252
# ...        ...          ...                        ...              ...
# 129703  129704  2018.557236                172.20.10.5     74.125.24.93
# 129704  129705  2018.646673                172.20.10.5  239.255.255.250
# 129705  129706  2018.670811               74.125.24.93      172.20.10.5
# 129706  129707  2018.670811               74.125.24.93      172.20.10.5
# 129707  129708  2018.671179                172.20.10.5     74.125.24.93
#
#        Protocol  Length                          Info
# ...

# %%
df_ytb_protocol = df_ytb_all[(df_ytb_all['Protocol'] == 'UDP') | (df_ytb_all['Protocol'] == 'TCP')]
df_ytb_protocol = df_ytb_protocol[['No.', 'Time', 'Length']]

# %%
df_ytb_time = df_ytb_protocol[(df_ytb_protocol['Time'] < 1200.000000) & (df_ytb_protocol['Time'] > 600.00000 )]
df_ytb_time
# Out:
#          No.         Time  Length
# 49821  49822   602.107661     866
# 49822  49823   602.110935    1165
# 49823  49824   602.113304    1392
# 49824  49825   602.113394     415
# 49825  49826   602.113679     498
# ...      ...          ...     ...
# 90905  90906  1196.937480      55
# 90906  90907  1196.937498      55
# 90907  90908  1197.141124      54
# 90908  90909  1197.141124      54
# 90909  90910  1197.141124      54
#
# [40356 rows x 3 columns]

# %%
df_length = df_ytb_time['Length']
plt.plot(df_length)

# %%
sns.distplot(df_ytb_time['Length'])
plt.show()
# Out:
# /home/indra/.local/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(data=df_ytb_time)
plt.show()

# %%
df1 = pd.Series(df_ytb_time['Length']).value_counts().reset_index().sort_values('Length').reset_index(drop=True)
df1.columns = ['Length', 'Frequency']
dff = df1['Frequency']
df1[['Frequency','Length']].hist()

plt.show()
